# %% [markdown]
# # Plotting result Unlynx vs Prio

# %%
import numpy as np
import matplotlib.pyplot as plt
import pylab
import re
import numpy as np
# %matplotlib inline

def plot(path):
    data = []
    for p in path :
        fp = open(p)
        unit = "ms"

        for line in fp.readlines():
            if(line!=""):
                dataS = (re.findall(r'\d*[.]\d*',line))
                newUnit = (re.findall(r'[a-z|µ]{1,}',line))[0]
                if(newUnit[0]=='s'):
                    data.append(float(dataS[0])*1000)
                elif(newUnit[:2]=="µs"):
                    data.append(float(dataS[0])/1000)
                else :
                    data.append(float(dataS[0]))
    fig3, ax3 = plt.subplots()
    ax3.set_title("time in " + unit)
    print("mean is",np.mean(data))
    print("std is",np.std(data))
    ax3.boxplot(data)
    return np.mean(data),np.std(data)

# %% [markdown]
# ## Variation with number of Client

# %% [markdown]
# x ad z will contains data about prio agg in function of # Client

# %%
x = []
z = []
y = [3,5,10,20,50,100,200,300,500]
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
# Out:
# mean is 10.9357986
# std is 4.9995277406
# mean is 10.9357986
# std is 4.9995277406
# mean is 10.9357986
# std is 4.9995277406
# mean is 10.9357986
# std is 4.9995277406
# mean is 10.9357986
# std is 4.9995277406
# mean is 10.9357986
# std is 4.9995277406
# mean is 10.9357986
# std is 4.9995277406
# mean is 10.9357986
# std is 4.9995277406
# mean is 10.9357986
# std is 4.9995277406

# %% [markdown]
# xp and zp will contain info about aggregation in unlynx in function in # of server

# %%
xp = []
zp = []
mean,std = plot(["IMPORT/3c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/5c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/10c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/20c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/50c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/100c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/200c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/300c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/500c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
# Out:
# mean is 75.5907726
# std is 6.12800308167
# mean is 148.3735529
# std is 13.172585358
# mean is 297.2327428
# std is 29.0944843826
# mean is 629.1968844
# std is 59.2827418779
# mean is 1409.8432138
# std is 69.9427431446
# mean is 2778.5759575
# std is 172.337177827
# mean is 5693.5924888
# std is 223.966617683
# mean is 8427.4445616
# std is 210.347351877
# mean is 14446.3008148
# std is 1821.39170498

# %%
xs = []
zs = []
mean,std = plot(["IMPORT/3c5s/prioInit.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/5c5s/prioInit.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/10c5s/prioInit.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/20c5s/prioInit.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/50c5s/prioInit.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/100c5s/prioInit.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/200c5s/prioInit.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/300c5s/prioInit.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/500c5s/prioInit.txt"])
xs.append(mean)
zs.append(std)
# Out:
# mean is 1.69081293333
# std is 0.32664104133
# mean is 1.92196202
# std is 0.724156766176
# mean is 2.06767108
# std is 0.907121011974
# mean is 2.031654165
# std is 1.10646087424
# mean is 2.040779492
# std is 1.24570380445
# mean is 2.02563087343
# std is 1.17359497379
# mean is 2.104337292
# std is 1.35913520911
# mean is 2.04835848467
# std is 1.26500115406
# mean is 2.11391072
# std is 1.63801075857

# %%
width = 0.5     # the width of the bars: can also be len(x) sequence


yi = [i for i in range(0, len(y))]
plt.xticks([3,5,10,20,50,100,200,300,500])
plt.xticks(yi, y)
p1 = plt.bar(yi,xs,width,yerr=zs)
p2 = plt.bar(yi, x, width, yerr=z,bottom=xs)
plt.annotate(str(x[0])[:4],xy=(-0.3,5))
plt.annotate(str(xp[0])[:4],xy=(-0.3,35))
plt.annotate(str(xp[3])[:5],xy=(2.7,35))
plt.annotate(str(xp[5])[:6],xy=(4.6,35))
plt.annotate(str(xp[8])[:7],xy=(7.6,35))
plt.annotate(str(xs[0])[:3],xy=(-0.3,0.5))
plt.annotate(str(xs[3])[:3],xy=(2.7,0.5))
plt.annotate(str(xs[5])[:3],xy=(4.7,0.5))
plt.annotate(str(xs[8])[:3],xy=(7.4,0.5))
p3 = plt.bar(yi,xp,width, yerr =zp,bottom=x)

plt.ylabel('Execution time in ms')
plt.title('Number of dataprovider')
plt.yscale('log')
plt.legend((p1[0], p2[0],p3[0]), ('Initialization', 'Aggregation','Input range validation'))

# %%
xa = []
za = []
mean,std = plot(["IMPORT/500c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/500c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/500c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/500c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/500c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/500c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/500c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/500c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/500c5s/agg.txt"])
xa.append(mean)
za.append(std)
# Out:
# mean is 10.1681236
# std is 3.59258640541
# mean is 10.1681236
# std is 3.59258640541
# mean is 10.1681236
# std is 3.59258640541
# mean is 10.1681236
# std is 3.59258640541
# mean is 10.1681236
# std is 3.59258640541
# mean is 10.1681236
# std is 3.59258640541
# mean is 10.1681236
# std is 3.59258640541
# mean is 10.1681236
# std is 3.59258640541
# mean is 10.1681236
# std is 3.59258640541

# %%
xv = []
zv = []

mean,std = plot(["IMPORT/500c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/500c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/500c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/500c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/500c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/500c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/500c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/500c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/500c5s/verif.txt"])
xv.append(mean)
zv.append(std)
# Out:
# mean is 62.5842642888
# std is 5.98745046647
# mean is 62.5842642888
# std is 5.98745046647
# mean is 62.5842642888
# std is 5.98745046647
# mean is 62.5842642888
# std is 5.98745046647
# mean is 62.5842642888
# std is 5.98745046647
# mean is 62.5842642888
# std is 5.98745046647
# mean is 62.5842642888
# std is 5.98745046647
# mean is 62.5842642888
# std is 5.98745046647
# mean is 62.5842642888
# std is 5.98745046647

# %%
xi = []
zi = []

mean,std = plot(["IMPORT/500c5s/init.txt"])
xi.append(mean)
zi.append(std)
mean,std = plot(["IMPORT/500c5s/init.txt"])
xi.append(mean)
zi.append(std)
mean,std = plot(["IMPORT/500c5s/init.txt"])
xi.append(mean)
zi.append(std)
mean,std = plot(["IMPORT/500c5s/init.txt"])
xi.append(mean)
zi.append(std)
mean,std = plot(["IMPORT/500c5s/init.txt"])
xi.append(mean)
zi.append(std)
mean,std = plot(["IMPORT/500c5s/init.txt"])
xi.append(mean)
zi.append(std)
mean,std = plot(["IMPORT/500c5s/init.txt"])
xi.append(mean)
zi.append(std)
mean,std = plot(["IMPORT/500c5s/init.txt"])
xi.append(mean)
zi.append(std)
mean,std = plot(["IMPORT/500c5s/init.txt"])
xi.append(mean)
zi.append(std)
# Out:
# mean is 2.71251736
# std is 1.27774972086
# mean is 2.71251736
# std is 1.27774972086
# mean is 2.71251736
# std is 1.27774972086
# mean is 2.71251736
# std is 1.27774972086
# mean is 2.71251736
# std is 1.27774972086
# mean is 2.71251736
# std is 1.27774972086
# mean is 2.71251736
# std is 1.27774972086
# mean is 2.71251736
# std is 1.27774972086
# mean is 2.71251736
# std is 1.27774972086

# %%
xdp = []
zdp = []

mean,std = plot(["IMPORT/500c5s/dptime.txt"])
xdp.append(mean)
zdp.append(std)
mean,std = plot(["IMPORT/500c5s/dptime.txt"])
xdp.append(mean)
zdp.append(std)
mean,std = plot(["IMPORT/500c5s/dptime.txt"])
xdp.append(mean)
zdp.append(std)
mean,std = plot(["IMPORT/500c5s/dptime.txt"])
xdp.append(mean)
zdp.append(std)
mean,std = plot(["IMPORT/500c5s/dptime.txt"])
xdp.append(mean)
zdp.append(std)
mean,std = plot(["IMPORT/500c5s/dptime.txt"])
xdp.append(mean)
zdp.append(std)
mean,std = plot(["IMPORT/500c5s/dptime.txt"])
xdp.append(mean)
zdp.append(std)
mean,std = plot(["IMPORT/500c5s/dptime.txt"])
xdp.append(mean)
zdp.append(std)
mean,std = plot(["IMPORT/500c5s/dptime.txt"])
xdp.append(mean)
zdp.append(std)
# Out:
# mean is 46.9951442863
# std is 5.53300839924
# mean is 46.9951442863
# std is 5.53300839924
# mean is 46.9951442863
# std is 5.53300839924
# mean is 46.9951442863
# std is 5.53300839924
# mean is 46.9951442863
# std is 5.53300839924
# mean is 46.9951442863
# std is 5.53300839924
# mean is 46.9951442863
# std is 5.53300839924
# mean is 46.9951442863
# std is 5.53300839924
# mean is 46.9951442863
# std is 5.53300839924

# %%
xsw = []
zsw = []

mean,std = plot(["IMPORT/500c5s/switch.txt"])
xsw.append(mean)
zsw.append(std)
mean,std = plot(["IMPORT/500c5s/switch.txt"])
xsw.append(mean)
zsw.append(std)
mean,std = plot(["IMPORT/500c5s/switch.txt"])
xsw.append(mean)
zsw.append(std)
mean,std = plot(["IMPORT/500c5s/switch.txt"])
xsw.append(mean)
zsw.append(std)
mean,std = plot(["IMPORT/500c5s/switch.txt"])
xsw.append(mean)
zsw.append(std)
mean,std = plot(["IMPORT/500c5s/switch.txt"])
xsw.append(mean)
zsw.append(std)
mean,std = plot(["IMPORT/500c5s/switch.txt"])
xsw.append(mean)
zsw.append(std)
mean,std = plot(["IMPORT/500c5s/switch.txt"])
xsw.append(mean)
zsw.append(std)
mean,std = plot(["IMPORT/500c5s/switch.txt"])
xsw.append(mean)
zsw.append(std)
# Out:
# mean is 56.1819568
# std is 5.41469853697
# mean is 66.8851952
# std is 8.97046996888
# mean is 69.8714366
# std is 11.9208579878
# mean is 68.5744795
# std is 12.4419784268
# mean is 72.4644733
# std is 20.0115501591
# mean is 67.1572778
# std is 6.10408383996
# mean is 69.685937
# std is 6.75465594886
# mean is 64.9892904
# std is 5.11496197541
# mean is 73.2085562
# std is 8.49556001367

# %% [markdown]
# ## Variation in number of server

# %%
x = []
z = []
y = [5,10,15,20,30,50]
mean,std = plot(["IMPORT/10c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/10c10s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/10c15s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/10c20s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/10c30s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/10c50s/prioAgg.txt"])
x.append(mean)
z.append(std)
# Out:
# mean is 14.1029034
# std is 3.03059204339
# mean is 38.6394498
# std is 7.8707874282
# mean is 68.5663962
# std is 5.28213062286
# mean is 124.7278748
# std is 6.80418804398
# mean is 248.758319667
# std is 11.4278860284
# mean is 614.602648667
# std is 69.1134426336

# %%
xp = []
zp = []

mean,std = plot(["IMPORT/10c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/10c10s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/10c15s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/10c20s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/10c30s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/10c50s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
# Out:
# mean is 212.1655695
# std is 40.6080816155
# mean is 749.6918366
# std is 87.5800787036
# mean is 1482.0164756
# std is 334.214735533
# mean is 2174.2612264
# std is 224.819520426
# mean is 4715.878708
# std is 730.011123422
# mean is 12016.6093774
# std is 4364.28049609

# %%
xa = []
za = []

mean,std = plot(["IMPORT/10c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/10c10s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/10c15s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/10c20s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/10c30s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/10c50s/agg.txt"])
xa.append(mean)
za.append(std)
# Out:
# mean is 11.0116602
# std is 1.61094566361
# mean is 35.1146322
# std is 2.74138026503
# mean is 71.1869032
# std is 8.504850559
# mean is 117.6722
# std is 5.26294886782
# mean is 250.3524946
# std is 5.96447254717
# mean is 766.665530833
# std is 17.2978610766

# %%
xv = []
zv = []

mean,std = plot(["IMPORT/10c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/10c10s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/10c15s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/10c20s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/10c30s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/10c50s/verif.txt"])
xv.append(mean)
zv.append(std)
# Out:
# mean is 150.975262444
# std is 4.24683073295
# mean is 363.6684861
# std is 70.6054734533
# mean is 565.5216933
# std is 110.539628189
# mean is 732.2755563
# std is 57.3593132886
# mean is 1291.8224733
# std is 321.367091675
# mean is 2643.3447685
# std is 760.193187184

# %%
xs = []
zs = []

mean,std = plot(["IMPORT/10c5s/switch.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/10c10s/switch.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/10c15s/switch.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/10c20s/switch.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/10c30s/switch.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/10c50s/switch.txt"])
xs.append(mean)
zs.append(std)
# Out:
# mean is 78.07715
# std is 7.24536655313
# mean is 194.3044256
# std is 14.8150422743
# mean is 345.7328686
# std is 52.1405835798
# mean is 444.4635832
# std is 32.8478961561
# mean is 820.3907156
# std is 56.2277565298
# mean is 1785.20395
# std is 63.8223125688

# %%
fig, ax = plt.subplots()

plt.yscale('log')

plt.xlabel('Number of data provider',fontsize=15)
plt.ylabel('Execution time in ms',fontsize=15)

# create an index for each tick position
ax.plot(y,x,'k--',label='Prio Aggregatio,')
ax.plot(y,xp,label='Prio Proof')
ax.plot(y,xs,label='Unlynx Switch')
ax.plot(y,xa,label='Unlynx Agg')
ax.plot(y,xv,label='Unlynx Range')
#ax.plot(y,xpp,label='prioProof')
fig.suptitle("Evolution of the execution time in function of number of server", fontsize=16)
legend = plt.legend(bbox_to_anchor=(1.5, 0.4), loc=1, borderaxespad=0.,fontsize=12)

plt.savefig('prioServer.png')
#Put more smaller number of server
