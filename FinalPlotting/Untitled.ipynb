# %% [markdown]
# # Plotting result Unlynx vs Prio

# %%
#Function to import stuff
import numpy as np
import matplotlib.lines as mlines
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import pylab
import re
import numpy as np
# %matplotlib inline

def plot(path):
    data = []
    for p in path :
        fp = open(p)
        unit = "ms"

        for line in fp.readlines():
            if(line!=""):
                dataS = (re.findall(r'\d*[.]\d*',line))
                newUnit = (re.findall(r'[a-z|µ]{1,}',line))[0]
                if(newUnit[0]=='s'):
                    data.append(float(dataS[0])*1000)
                elif(newUnit[:2]=="µs"):
                    data.append(float(dataS[0])/1000)
                else :
                    data.append(float(dataS[0]))
    fig3, ax3 = plt.subplots()
    ax3.set_title("time in " + unit)
    print("mean is",np.mean(data))
    print("std is",np.std(data))
    ax3.boxplot(data)
    return np.mean(data),np.std(data)

# %% [markdown]
# ## Variation with number of Client

# %% [markdown]
# x ad z will contains data about prio agg in function of # Client

# %%
x = []
z = []
y = [3,5,10,20,50,100,200,300,500]
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
# Out:
# mean is 10.9357986
# std is 4.99952774059807
# mean is 10.9357986
# std is 4.99952774059807
# mean is 10.9357986
# std is 4.99952774059807
# mean is 10.9357986
# std is 4.99952774059807
# mean is 10.9357986
# std is 4.99952774059807
# mean is 10.9357986
# std is 4.99952774059807
# mean is 10.9357986
# std is 4.99952774059807
# mean is 10.9357986
# std is 4.99952774059807
# mean is 10.9357986
# std is 4.99952774059807

# %% [markdown]
# xp and zp will contain info about aggregation in unlynx in function in # of server

# %%
xp = []
zp = []
mean,std = plot(["IMPORT/3c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/5c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/10c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/20c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/50c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/100c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/200c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/300c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/500c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
# Out:
# mean is 75.59077260000001
# std is 6.128003081670397
# mean is 148.37355290000002
# std is 13.172585357973002
# mean is 297.2327428
# std is 29.094484382616237
# mean is 629.1968844
# std is 59.28274187791817
# mean is 1409.8432138
# std is 69.9427431445894
# mean is 2778.5759575
# std is 172.33717782654892
# mean is 5693.5924888
# std is 223.96661768313496
# mean is 8427.4445616
# std is 210.34735187739543
# mean is 14446.300814799999
# std is 1821.3917049791864

# %%
xs = []
zs = []
mean,std = plot(["IMPORT/3c5s/prioInit.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/5c5s/prioInit.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/10c5s/prioInit.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/20c5s/prioInit.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/50c5s/prioInit.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/100c5s/prioInit.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/200c5s/prioInit.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/300c5s/prioInit.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/500c5s/prioInit.txt"])
xs.append(mean)
zs.append(std)
# Out:
# mean is 1.6908129333333335
# std is 0.32664104133048283
# mean is 1.92196202
# std is 0.7241567661764817
# mean is 2.06767108
# std is 0.9071210119738785
# mean is 2.031654165
# std is 1.1064608742411084
# mean is 2.040779492
# std is 1.2457038044487052
# mean is 2.025630873429084
# std is 1.1735949737874287
# mean is 2.1043372920000003
# std is 1.3591352091067859
# mean is 2.0483584846666667
# std is 1.265001154064258
# mean is 2.11391072
# std is 1.6380107585734531

# %%
xa = []
za = []
mean,std = plot(["IMPORT/500c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/500c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/500c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/500c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/500c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/500c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/500c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/500c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/500c5s/agg.txt"])
xa.append(mean)
za.append(std)
# Out:
# mean is 10.1681236
# std is 3.5925864054075913
# mean is 10.1681236
# std is 3.5925864054075913
# mean is 10.1681236
# std is 3.5925864054075913
# mean is 10.1681236
# std is 3.5925864054075913
# mean is 10.1681236
# std is 3.5925864054075913
# mean is 10.1681236
# std is 3.5925864054075913
# mean is 10.1681236
# std is 3.5925864054075913
# mean is 10.1681236
# std is 3.5925864054075913
# mean is 10.1681236
# std is 3.5925864054075913

# %%
xv = []
zv = []

mean,std = plot(["IMPORT/500c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/500c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/500c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/500c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/500c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/500c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/500c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/500c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/500c5s/verif.txt"])
xv.append(mean)
zv.append(std)
# Out:
# mean is 62.58426428880001
# std is 5.987450466472464
# mean is 62.58426428880001
# std is 5.987450466472464
# mean is 62.58426428880001
# std is 5.987450466472464
# mean is 62.58426428880001
# std is 5.987450466472464
# mean is 62.58426428880001
# std is 5.987450466472464
# mean is 62.58426428880001
# std is 5.987450466472464
# mean is 62.58426428880001
# std is 5.987450466472464
# mean is 62.58426428880001
# std is 5.987450466472464
# mean is 62.58426428880001
# std is 5.987450466472464

# %%
xi = []
zi = []

mean,std = plot(["IMPORT/500c5s/init.txt"])
xi.append(mean)
zi.append(std)
mean,std = plot(["IMPORT/500c5s/init.txt"])
xi.append(mean)
zi.append(std)
mean,std = plot(["IMPORT/500c5s/init.txt"])
xi.append(mean)
zi.append(std)
mean,std = plot(["IMPORT/500c5s/init.txt"])
xi.append(mean)
zi.append(std)
mean,std = plot(["IMPORT/500c5s/init.txt"])
xi.append(mean)
zi.append(std)
mean,std = plot(["IMPORT/500c5s/init.txt"])
xi.append(mean)
zi.append(std)
mean,std = plot(["IMPORT/500c5s/init.txt"])
xi.append(mean)
zi.append(std)
mean,std = plot(["IMPORT/500c5s/init.txt"])
xi.append(mean)
zi.append(std)
mean,std = plot(["IMPORT/500c5s/init.txt"])
xi.append(mean)
zi.append(std)
# Out:
# mean is 2.71251736
# std is 1.2777497208606037
# mean is 2.71251736
# std is 1.2777497208606037
# mean is 2.71251736
# std is 1.2777497208606037
# mean is 2.71251736
# std is 1.2777497208606037
# mean is 2.71251736
# std is 1.2777497208606037
# mean is 2.71251736
# std is 1.2777497208606037
# mean is 2.71251736
# std is 1.2777497208606037
# mean is 2.71251736
# std is 1.2777497208606037
# mean is 2.71251736
# std is 1.2777497208606037

# %%
xdp = []
zdp = []

mean,std = plot(["IMPORT/500c5s/dptime.txt"])
xdp.append(mean)
zdp.append(std)
mean,std = plot(["IMPORT/500c5s/dptime.txt"])
xdp.append(mean)
zdp.append(std)
mean,std = plot(["IMPORT/500c5s/dptime.txt"])
xdp.append(mean)
zdp.append(std)
mean,std = plot(["IMPORT/500c5s/dptime.txt"])
xdp.append(mean)
zdp.append(std)
mean,std = plot(["IMPORT/500c5s/dptime.txt"])
xdp.append(mean)
zdp.append(std)
mean,std = plot(["IMPORT/500c5s/dptime.txt"])
xdp.append(mean)
zdp.append(std)
mean,std = plot(["IMPORT/500c5s/dptime.txt"])
xdp.append(mean)
zdp.append(std)
mean,std = plot(["IMPORT/500c5s/dptime.txt"])
xdp.append(mean)
zdp.append(std)
mean,std = plot(["IMPORT/500c5s/dptime.txt"])
xdp.append(mean)
zdp.append(std)
# Out:
# mean is 46.995144286320006
# std is 5.533008399243851
# mean is 46.995144286320006
# std is 5.533008399243851
# mean is 46.995144286320006
# std is 5.533008399243851
# mean is 46.995144286320006
# std is 5.533008399243851
# mean is 46.995144286320006
# std is 5.533008399243851
# mean is 46.995144286320006
# std is 5.533008399243851
# mean is 46.995144286320006
# std is 5.533008399243851
# mean is 46.995144286320006
# std is 5.533008399243851
# mean is 46.995144286320006
# std is 5.533008399243851

# %%
xsw = []
zsw = []

mean,std = plot(["IMPORT/500c5s/switch.txt"])
xsw.append(mean)
zsw.append(std)
mean,std = plot(["IMPORT/500c5s/switch.txt"])
xsw.append(mean)
zsw.append(std)
mean,std = plot(["IMPORT/500c5s/switch.txt"])
xsw.append(mean)
zsw.append(std)
mean,std = plot(["IMPORT/500c5s/switch.txt"])
xsw.append(mean)
zsw.append(std)
mean,std = plot(["IMPORT/500c5s/switch.txt"])
xsw.append(mean)
zsw.append(std)
mean,std = plot(["IMPORT/500c5s/switch.txt"])
xsw.append(mean)
zsw.append(std)
mean,std = plot(["IMPORT/500c5s/switch.txt"])
xsw.append(mean)
zsw.append(std)
mean,std = plot(["IMPORT/500c5s/switch.txt"])
xsw.append(mean)
zsw.append(std)
mean,std = plot(["IMPORT/500c5s/switch.txt"])
xsw.append(mean)
zsw.append(std)
# Out:
# mean is 73.2085562
# std is 8.49556001367188
# mean is 73.2085562
# std is 8.49556001367188
# mean is 73.2085562
# std is 8.49556001367188
# mean is 73.2085562
# std is 8.49556001367188
# mean is 73.2085562
# std is 8.49556001367188
# mean is 73.2085562
# std is 8.49556001367188
# mean is 73.2085562
# std is 8.49556001367188
# mean is 73.2085562
# std is 8.49556001367188
# mean is 73.2085562
# std is 8.49556001367188

# %%
def autolabel(rects, ax):
    incremental = 0
    for rect in rects:
        y_val = rect.get_y() + rect.get_height() - rect.get_height() + 2
        if(rect.get_height()>1000):
            y_val += 150 + incremental
            incremental += 30
        if(rect.get_height()>12):
            y_val += 30
        bl = rect.get_xy()
        x = 0.5*rect.get_width() + bl[0]
        y = 0.5*rect.get_height() + bl[1]
        ax.text(x, y, int(rect.get_height()), ha='center',va='center')
       ## ax.text(rect.get_x() + rect.get_width()/2., y_val,
         #       int(rect.get_height()),
          #      ha='center', va='center',fontsize=8)

# %%
def unlynxTotal(p1,p2,p3,p4,p5):
    for r1,r2,r3,r4,r5 in zip(p1,p2,p3,p4,p5):
        h1 = r1.get_height()
        h2 = r2.get_height()
        h3 = r3.get_height()
        h4 = r4.get_height()
        h5 = r5.get_height()
        plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3+h4+h5, '%s'% int(h1+h2+h3+h4+h5), ha = 'center', va='bottom',fontsize=8)

# %%
def prioTotal(p1,p2,p3):
    for r1,r2,r3 in zip(p1,p2,p3):
        h1 = r1.get_height()
        h2 = r2.get_height()
        h3 = r3.get_height()
        plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% int(h1+h2+h3), ha = 'center', va='bottom',fontsize=8)

# %%
plt.figure(figsize=(7,7), dpi=300)
dpservRatio = np.ceil(np.array(y)/5)
xvall = np.multiply(dpservRatio,xv)
groups = [[xs,x,xp],[xi,xa,xdp,xsw,xvall],[xi,xa,np.multiply(xdp,5),xsw,np.multiply(xv,y)]]
group_labels = y
num_items = len(group_labels)
# This needs to be a numpy range for xdata calculations
# to work.
ind = np.arange(num_items)

# Bar graphs expect a total width of "1.0" per group
# Thus, you should make the sum of the two margins
# plus the sum of the width for each entry equal 1.0.
# One way of doing that is shown below. You can make
# The margins smaller if they're still too big.
margin = 0.05
width = 0.25
#Colour for init
colour_classes = ['#ffcccc','#ff6666','#ff0000']
#Colour for aggregation
colour_agg = ['#adebad','#5cd65c',"#29a329"]
#Colour for Verif
colour_verif = ['#668cff','#3366ff','#0040ff']
#Colour DP
colour_dp = ['#ffb84d','#e68a00']
#Colour switch
colour_sw = ['#d2a679','#ac7339']


s = plt.subplot(1,1,1)

for num, vals in enumerate(groups):
    
    # The position of the xdata must be calculated for each of the two data series
    xdata = ind+margin+(num*0.30)
    # Removing the "align=center" feature will left align graphs, which is what
    # this method of calculating positions assumes
    
    #PRIO
    if(num==0):
        p0 = plt.bar(xdata, vals[0], width, color=colour_classes[1])
        #autolabel(p0,plt)
        p1 = plt.bar(xdata, vals[1], width,bottom=vals[0], color=colour_agg[1])
        #autolabel(p1,plt)
        p2 = plt.bar(xdata, vals[2], width,bottom=vals[1],color=colour_verif[1])
        #autolabel(p0+p1+p2,plt)
        prioTotal(p0,p1,p2)
    plt.yscale('log')
    #Unlynx Anytrust
    if(num==1):
        p3 = plt.bar(xdata,vals[0],width, color=colour_classes[num],hatch="/")
        #autolabel(p3,plt)
        p4 = plt.bar(xdata,vals[1], width,bottom=vals[0],color=colour_agg[num],hatch="/")
        #autolabel(p4,plt)
        p5 = plt.bar(xdata,vals[2],width,bottom=(np.array(vals[0])+np.array(vals[1])),color=colour_dp[num-1],hatch="/")
        #autolabel(p5,plt)
        p6 = plt.bar(xdata,vals[3],width,bottom=(np.array(vals[0])+np.array(vals[1])+np.array(vals[2])),color=colour_sw[num-1],hatch="/")
        #autolabel(p6,plt)
        p7 = plt.bar(xdata,vals[4],width,bottom=(np.array(vals[0])+np.array(vals[1])+np.array(vals[2])+np.array(vals[3])),color=colour_verif[num],hatch="/")
        #autolabel(p7,plt)
        unlynxTotal(p3,p4,p5,p6,p7)
    #Unlynx All trusted
    if(num==2):
        p8 = plt.bar(xdata,vals[0],width, color=colour_classes[1])
        #autolabel(p8,plt)
        p9 = plt.bar(xdata,vals[1], width,bottom=(np.array(vals[0])),color=colour_agg[1],hatch="-")
        #autolabel(p9,plt)
        p10 = plt.bar(xdata,vals[2],width,bottom=(np.array(vals[0])+np.array(vals[1])),color=colour_dp[0],hatch="-")
        #autolabel(p10,plt)
        p11 = plt.bar(xdata,vals[3],width,bottom=(np.array(vals[0])+np.array(vals[1])+np.array(vals[2])),color=colour_sw[0],hatch="-")
        #autolabel(p11,plt)
        p12 = plt.bar(xdata,vals[4],width,bottom=(np.array(vals[0])+np.array(vals[1])+np.array(vals[2])+np.array(vals[3])),color=colour_verif[1],hatch="-")
        #autolabel(p12,plt)
        unlynxTotal(p8,p9,p10,p11,p12)
        #plt.legend((p0[0],p3[0],p8[0],p1[0],p4[0],p9[0],p2[0],p7[0],p12[0],p5[0],p10[0],p6[0],p11[0]),(
         #   'Prio Initialization','Unlynx All trusted Initialization','Unlynx Anytrust Initialization',
          #  'Prio Aggregation','Unlynx All trusted Aggregation','Unlynx Anytrust Initilaization',
        #'Prio Input validation','Unlynx All trusted Input validation','Unlynx Anytrust Input validation',
        #'Unlynx All trusted DP proof computation','Unlynx Anytrust Anytrust DP proof computation',
        #'Unlynx All trusted Keyswitch','Unlynx Anytrust Keyswitch'),
        #         bbox_to_anchor=(1., 1))
        
        prio =  patches.Rectangle(
        (0.3, 0.3), 1, 1, fill=False,label='Prio')
        unlynxTrus =  patches.Rectangle(
        (0.1, 0.1), 1, 1,
        hatch='//', fill=False,label='Unlynx Trusted')
        Unlynx =  patches.Rectangle(
        (1, 1), 1, 1,
        hatch='---', fill=False,label='Unlynx')
       
        
        init = mlines.Line2D([], [], color=colour_classes[1],marker='s', linestyle='None',
                          markersize=12, label='Initialisation')
        verif = mlines.Line2D([], [], color=colour_verif[1], marker='s', linestyle='None',
                          markersize=12, label='Proof Verification')
        dp = mlines.Line2D([], [], color=colour_dp[0], marker='s', linestyle='None',
                          markersize=12, label='Data provider proof computation')
        switch = mlines.Line2D([], [], color=colour_sw[0], marker='s', linestyle='None',
                          markersize=12, label='Key switch')
        agg = mlines.Line2D([], [], color=colour_agg[1], marker='s', linestyle='None',
                          markersize=12, label='Aggregation')
        
        plt.legend(handles=[prio,unlynxTrus,Unlynx,init,verif,dp,agg,switch],prop={'size': 8})
        
        plt.xlabel('Number of Data providers',fontsize=14)
        plt.ylabel('Execution time in ms',fontsize=14)
        #plt.title('Comparison of Prio, Unlynx Trusted and Unlynx Anytrust execution time in function of the number of Data providers')
# You should no longer need to manually set the plot limit since everything 
# is scaled to one.
# Also the ticks should be much simpler now that each group of bars extends from
# 0.0 to 1.0, 1.0 to 2.0, and so forth and, thus, are centered at 0.5, 1.5, etc.
s.set_xticks(ind+0.5)
s.set_xticklabels(group_labels)
plt.savefig('ComparisonDPPPTX.png')

# %%
plt.figure(figsize=(7,7), dpi=400)
dpservRatio = np.ceil(np.array(y)/5)
xvall = np.multiply(dpservRatio,xv)
groups = [[xs[:3],xp[:3],x[:3]],[xi[:3],xdp[:3],xvall[:3],xa[:3],xsw[:3]],[xi[:3],np.multiply(xdp[:3],5),np.multiply(xv[:3],[3,5,10]),xa[:3],xsw[:3]]]
group_labels = [3,5,10]
num_items = len(group_labels)
# This needs to be a numpy range for xdata calculations
# to work.
ind = np.arange(num_items)

# Bar graphs expect a total width of "1.0" per group
# Thus, you should make the sum of the two margins
# plus the sum of the width for each entry equal 1.0.
# One way of doing that is shown below. You can make
# The margins smaller if they're still too big.
margin = 0.05
width = 0.25
#Colour for init
colour_classes = ['#ffcccc','#ff6666','#ff0000']
#Colour for aggregation
colour_agg = ['#adebad','#5cd65c',"#29a329"]
#Colour for Verif
colour_verif = ['#668cff','#3366ff','#0040ff']
#Colour DP
colour_dp = ['#ffb84d','#e68a00']
#Colour switch
colour_sw = ['#d2a679','#ac7339']


s = plt.subplot(1,1,1)

for num, vals in enumerate(groups):
    
    # The position of the xdata must be calculated for each of the two data series
    xdata = ind+margin+(num*0.30)
    # Removing the "align=center" feature will left align graphs, which is what
    # this method of calculating positions assumes
    
    #PRIO
    if(num==0):
        p0 = plt.bar(xdata, vals[0], width, color=colour_classes[1])
        
        p1 = plt.bar(xdata, vals[1], width,bottom=vals[0], color=colour_verif[1])
        autolabel(p1,plt)
        p2 = plt.bar(xdata, vals[2], width,bottom=(np.array(vals[0])+np.array(vals[1])),color=colour_agg[1])
        autolabel(p2,plt)
    #plt.yscale('log')
    #Unlynx Anytrust
    if(num==1):
        p3 = plt.bar(xdata,vals[0],width, color=colour_classes[num],hatch='/')
        p4 = plt.bar(xdata,vals[1], width,bottom=np.array(vals[0]),color=colour_dp[num-1],hatch='/')
        autolabel(p4,plt)
        p5 = plt.bar(xdata,vals[2],width,bottom=(np.array(vals[0])+np.array(vals[1])),color=colour_verif[num],hatch='/')
        autolabel(p5,plt)
        p6 = plt.bar(xdata,vals[3],width,bottom=(np.array(vals[0])+np.array(vals[1])+np.array(vals[2])),color=colour_agg[num],hatch='/')
        autolabel(p6,plt)
        p7 = plt.bar(xdata,vals[4],width,bottom=(np.array(vals[0])+np.array(vals[1])+np.array(vals[2]) +np.array(vals[3])),color=colour_sw[num-1],hatch='/')
        autolabel(p7,plt)
    #Unlynx All trusted
    if(num==2):
        p8 = plt.bar(xdata,vals[0],width, color=colour_classes[1],hatch='-')
        
        p9 = plt.bar(xdata,vals[1], width,bottom=vals[0],color=colour_dp[0],hatch='-')
        autolabel(p9,plt)
        p10 = plt.bar(xdata,vals[2],width,bottom=(np.array(vals[0])+np.array(vals[1])),color=colour_verif[0],hatch='-')
        autolabel(p10,plt)
        p11 = plt.bar(xdata,vals[3],width,bottom=(np.array(vals[0])+np.array(vals[1])+np.array(vals[2])),color=colour_agg[num],hatch='-')
        autolabel(p11,plt)
        p12 = plt.bar(xdata,vals[4],width,bottom=(np.array(vals[0])+np.array(vals[1])+np.array(vals[2]) +np.array(vals[3])),color=colour_sw[0],hatch='-')
        autolabel(p12,plt)
        
        
        prio =  patches.Rectangle(
        (0.3, 0.3), 1, 1, fill=False,label='Prio')
        unlynxTrus =  patches.Rectangle(
        (0.1, 0.1), 1, 1,
        hatch='//', fill=False,label='Unlynx Trusted')
        Unlynx =  patches.Rectangle(
        (1, 1), 1, 1,
        hatch='---', fill=False,label='Unlynx')
       
        
        init = mlines.Line2D([], [], color=colour_classes[1],marker='s', linestyle='None',
                          markersize=12, label='Initialisation')
        verif = mlines.Line2D([], [], color=colour_verif[1], marker='s', linestyle='None',
                          markersize=12, label='Proof Verification')
        dp = mlines.Line2D([], [], color=colour_dp[0], marker='s', linestyle='None',
                          markersize=12, label='Data provider proof computation')
        switch = mlines.Line2D([], [], color=colour_sw[0], marker='s', linestyle='None',
                          markersize=12, label='Key switch')
        agg = mlines.Line2D([], [], color=colour_agg[1], marker='s', linestyle='None',
                          markersize=12, label='Aggregation')
        
        plt.legend(handles=[prio,unlynxTrus,Unlynx,init,verif,dp,agg,switch])
        
        plt.xlabel('Number of Data providers',fontsize=14)
        plt.ylabel('Execution time in ms',fontsize=14)
        #plt.title('Comparison of Prio, Unlynx Trusted and Unlynx Anytrust execution time in function of the number of Data providers')
# You should no longer need to manually set the plot limit since everything 
# is scaled to one.
# Also the ticks should be much simpler now that each group of bars extends from
# 0.0 to 1.0, 1.0 to 2.0, and so forth and, thus, are centered at 0.5, 1.5, etc.
s.set_xticks(ind+0.5)
s.set_xticklabels(group_labels)
plt.savefig('ComparisonlinearDPPPTX')

# %% [markdown]
# ## Variation in number of server

# %%
xx = []
zz = []
yy = [3,5,10,15,20,30,50]

mean,std = plot(["IMPORT/10c3s/prioAgg.txt"])
xx.append(mean)
zz.append(std)
mean,std = plot(["IMPORT/10c5s/prioAgg.txt"])
xx.append(mean)
zz.append(std)
mean,std = plot(["IMPORT/10c10s/prioAgg.txt"])
xx.append(mean)
zz.append(std)
mean,std = plot(["IMPORT/10c15s/prioAgg.txt"])
xx.append(mean)
zz.append(std)
mean,std = plot(["IMPORT/10c20s/prioAgg.txt"])
xx.append(mean)
zz.append(std)
mean,std = plot(["IMPORT/10c30s/prioAgg.txt"])
xx.append(mean)
zz.append(std)
mean,std = plot(["IMPORT/10c50s/prioAgg.txt"])
xx.append(mean)
zz.append(std)
# Out:
# mean is 3.3621537
# std is 1.00626453353
# mean is 8.8029581
# std is 1.91986156865
# mean is 29.2801145
# std is 6.19734621066
# mean is 66.3338057
# std is 4.71148101368
# mean is 102.1254611
# std is 9.04765806818
# mean is 207.3056368
# std is 7.20691731866
# mean is 566.358396667
# std is 20.0360625812

# %%
xxp = []
zzp = []

mean,std = plot(["IMPORT/10c5s/prioVerif.txt"])
xxp.append(mean)
zzp.append(std)
mean,std = plot(["IMPORT/10c5s/prioVerif.txt"])
xxp.append(mean)
zzp.append(std)
mean,std = plot(["IMPORT/10c10s/prioVerif.txt"])
xxp.append(mean)
zzp.append(std)
mean,std = plot(["IMPORT/10c15s/prioVerif.txt"])
xxp.append(mean)
zzp.append(std)
mean,std = plot(["IMPORT/10c20s/prioVerif.txt"])
xxp.append(mean)
zzp.append(std)
mean,std = plot(["IMPORT/10c30s/prioVerif.txt"])
xxp.append(mean)
zzp.append(std)
mean,std = plot(["IMPORT/10c50s/prioVerif.txt"])
xxp.append(mean)
zzp.append(std)
# Out:
# mean is 297.2327428
# std is 29.0944843826
# mean is 297.2327428
# std is 29.0944843826
# mean is 780.7431935
# std is 78.4935682511
# mean is 1416.3438909
# std is 144.586955571
# mean is 2326.1742985
# std is 255.397540738
# mean is 4840.8776228
# std is 988.02321334
# mean is 10760.4174328
# std is 1192.09284217

# %%
xxi = []
zzi = []

mean,std = plot(["IMPORT/10c3s/prioInit.txt"])
xxi.append(mean)
zzi.append(std)
mean,std = plot(["IMPORT/10c5s/prioInit.txt"])
xxi.append(mean)
zzi.append(std)
mean,std = plot(["IMPORT/10c10s/prioInit.txt"])
xxi.append(mean)
zzi.append(std)
mean,std = plot(["IMPORT/10c15s/prioInit.txt"])
xxi.append(mean)
zzi.append(std)
mean,std = plot(["IMPORT/10c20s/prioInit.txt"])
xxi.append(mean)
zzi.append(std)
mean,std = plot(["IMPORT/10c30s/prioInit.txt"])
xxi.append(mean)
zzi.append(std)
mean,std = plot(["IMPORT/10c50s/prioInit.txt"])
xxi.append(mean)
zzi.append(std)
# Out:
# mean is 1.71691342
# std is 0.606050926133
# mean is 2.06767108
# std is 0.907121011974
# mean is 2.63260165
# std is 1.70224474313
# mean is 3.05299962
# std is 1.55439541581
# mean is 3.19524805
# std is 1.38316223517
# mean is 3.49692891
# std is 1.47156643964
# mean is 5.13133798333
# std is 2.19511492528

# %%
xxa = []
zza = []

mean,std = plot(["IMPORT/10c3s/agg.txt"])
xxa.append(mean)
zza.append(std)
mean,std = plot(["IMPORT/10c5s/agg.txt"])
xxa.append(mean)
zza.append(std)
mean,std = plot(["IMPORT/10c10s/agg.txt"])
xxa.append(mean)
zza.append(std)
mean,std = plot(["IMPORT/10c15s/agg.txt"])
xxa.append(mean)
zza.append(std)
mean,std = plot(["IMPORT/10c20s/agg.txt"])
xxa.append(mean)
zza.append(std)
mean,std = plot(["IMPORT/10c30s/agg.txt"])
xxa.append(mean)
zza.append(std)
mean,std = plot(["IMPORT/10c50s/agg.txt"])
xxa.append(mean)
zza.append(std)
# Out:
# mean is 5.5090878
# std is 2.2351641574
# mean is 10.4632024
# std is 2.82718436919
# mean is 45.4376372
# std is 10.4216763766
# mean is 105.0311069
# std is 17.7473728497
# mean is 163.101187
# std is 34.3380043979
# mean is 352.4502079
# std is 51.6388093995
# mean is 907.0256236
# std is 41.2110211932

# %%
xxv = []
zzv = []
##Error with 30 and 50 serv

mean,std = plot(["IMPORT/10c3s/verif.txt"])
xxv.append(mean)
zzv.append(std)
mean,std = plot(["IMPORT/10c5s/verif.txt"])
xxv.append(mean)
zzv.append(std)
mean,std = plot(["IMPORT/10c10s/verif.txt"])
xxv.append(mean)
zzv.append(std)
mean,std = plot(["IMPORT/10c15s/verif.txt"])
xxv.append(mean)
zzv.append(std)
mean,std = plot(["IMPORT/10c20s/verif.txt"])
xxv.append(mean)
zzv.append(std)
mean,std = plot(["IMPORT/10c20s/verif.txt"])
xxv.append(mean)
zzv.append(std)
mean,std = plot(["IMPORT/10c20s/verif.txt"])
xxv.append(mean)
zzv.append(std)
# Out:
# mean is 69.2169051867
# std is 14.9851662569
# mean is 61.148722548
# std is 7.09367423708
# mean is 62.913769275
# std is 7.48317573801
# mean is 62.4445230373
# std is 4.94495032714
# mean is 64.2989230544
# std is 11.5104492855
# mean is 64.2989230544
# std is 11.5104492855
# mean is 64.2989230544
# std is 11.5104492855

# %%
xxs = []
zzs = []

mean,std = plot(["IMPORT/10c3s/switch.txt"])
xxs.append(mean)
zzs.append(std)
mean,std = plot(["IMPORT/10c5s/switch.txt"])
xxs.append(mean)
zzs.append(std)
mean,std = plot(["IMPORT/10c10s/switch.txt"])
xxs.append(mean)
zzs.append(std)
mean,std = plot(["IMPORT/10c15s/switch.txt"])
xxs.append(mean)
zzs.append(std)
mean,std = plot(["IMPORT/10c20s/switch.txt"])
xxs.append(mean)
zzs.append(std)
mean,std = plot(["IMPORT/10c30s/switch.txt"])
xxs.append(mean)
zzs.append(std)
mean,std = plot(["IMPORT/10c50s/switch.txt"])
xxs.append(mean)
zzs.append(std)
# Out:
# mean is 41.3342965
# std is 10.7316301257
# mean is 69.8714366
# std is 11.9208579878
# mean is 233.0803394
# std is 42.1608775287
# mean is 410.0936429
# std is 43.087591059
# mean is 509.7868349
# std is 68.3238571322
# mean is 919.2672429
# std is 87.9591753495
# mean is 2020.7478358
# std is 94.2872815464

# %%
xxdp = []
zzdp = []

mean,std = plot(["IMPORT/10c3s/dptime.txt"])
xxdp.append(mean)
zzdp.append(std)
mean,std = plot(["IMPORT/10c5s/dptime.txt"])
xxdp.append(mean)
zzdp.append(std)
mean,std = plot(["IMPORT/10c10s/dptime.txt"])
xxdp.append(mean)
zzdp.append(std)
mean,std = plot(["IMPORT/10c15s/dptime.txt"])
xxdp.append(mean)
zzdp.append(std)
mean,std = plot(["IMPORT/10c20s/dptime.txt"])
xxdp.append(mean)
zzdp.append(std)
mean,std = plot(["IMPORT/10c30s/dptime.txt"])
xxdp.append(mean)
zzdp.append(std)
mean,std = plot(["IMPORT/10c50s/dptime.txt"])
xxdp.append(mean)
zzdp.append(std)
# Out:
# mean is 49.0287445967
# std is 8.09542876641
# mean is 45.583424402
# std is 4.13252812961
# mean is 46.965370319
# std is 4.80686067112
# mean is 46.5958857047
# std is 4.99247050233
# mean is 48.0565982121
# std is 9.86849882793
# mean is 46.341284547
# std is 5.94781450367
# mean is 46.93054136
# std is 8.18695244887

# %%
xxsi = []
zzsi = []

mean,std = plot(["IMPORT/10c3s/init.txt"])
xxsi.append(mean)
zzsi.append(std)
mean,std = plot(["IMPORT/10c5s/init.txt"])
xxsi.append(mean)
zzsi.append(std)
mean,std = plot(["IMPORT/10c10s/init.txt"])
xxsi.append(mean)
zzsi.append(std)
mean,std = plot(["IMPORT/10c15s/init.txt"])
xxsi.append(mean)
zzsi.append(std)
mean,std = plot(["IMPORT/10c20s/init.txt"])
xxsi.append(mean)
zzsi.append(std)
mean,std = plot(["IMPORT/10c30s/init.txt"])
xxsi.append(mean)
zzsi.append(std)
mean,std = plot(["IMPORT/10c50s/init.txt"])
xxsi.append(mean)
zzsi.append(std)
# Out:
# mean is 2.65674806667
# std is 0.895866292794
# mean is 2.50875738
# std is 0.418736800965
# mean is 2.7598171
# std is 1.01798112322
# mean is 2.81540716667
# std is 1.31746369618
# mean is 2.7723193
# std is 1.27423106376
# mean is 2.72026372667
# std is 1.01153574647
# mean is 2.669728896
# std is 0.782352908871

# %%
plt.figure(figsize=(7,7), dpi=300)
ratio = np.ceil(np.array([10,10,10,10,10,10,10])/np.array(yy))
xxvall = np.multiply(xxv,ratio)
group_labels = yy
groups = [[xxi,xx,xxp],[xxsi,xxa,xxdp,xxs,xxvall],[xxsi,xxa,np.multiply(xxdp,yy),xxs,np.multiply(xxv,10)]]
num_items = len(group_labels)

# Bar graphs expect a total width of "1.0" per group
# Thus, you should make the sum of the two margins
# plus the sum of the width for each entry equal 1.0.
# One way of doing that is shown below. You can make
ind = np.arange(num_items)
# The margins smaller if they're still too big.
margin = 0.05
width = 0.25
#Colour for init
colour_classes = ['#ffcccc','#ff6666','#ff0000']
#Colour for aggregation
colour_agg = ['#adebad','#5cd65c',"#29a329"]
#Colour for Verif
colour_verif = ['#668cff','#3366ff','#0040ff']
#Colour DP
colour_dp = ['#ffb84d','#e68a00']
#Colour switch
colour_sw = ['#d2a679','#ac7339']

s = plt.subplot(1,1,1)

for num, vals in enumerate(groups):
    
    # The position of the xdata must be calculated for each of the two data series
    xdata = ind+margin+(num*0.30)
    # Removing the "align=center" feature will left align graphs, which is what
    # this method of calculating positions assumes
    print(xdata)
    #PRIO
    if(num==0):
        p0 = plt.bar(xdata, vals[0], width, color=colour_classes[1])
        #autolabel(p0,plt)
        p1 = plt.bar(xdata, vals[1], width,bottom=vals[0], color=colour_agg[1])
        #autolabel(p1,plt)
        p2 = plt.bar(xdata, vals[2], width,bottom=vals[1],color=colour_verif[1])
        #autolabel(p2,plt)
        prioTotal(p0,p1,p2)
    plt.yscale('log')
    #Unlynx Anytrust
    if(num==1):
        p3 = plt.bar(xdata,vals[0],width, color=colour_classes[num],hatch='/')
        #autolabel(p3,plt)
        p4 = plt.bar(xdata,vals[1], width,bottom=vals[0],color=colour_agg[num],hatch='/')
        #autolabel(p4,plt)
        p5 = plt.bar(xdata,vals[2],width,bottom=(np.array(vals[0])+np.array(vals[1])),color=colour_dp[num-1],hatch='/')
        #autolabel(p5,plt)
        p6 = plt.bar(xdata,vals[3],width,bottom=(np.array(vals[0])+np.array(vals[1])+np.array(vals[2])),color=colour_sw[num-1],hatch='/')
        #autolabel(p6,plt)
        p7 = plt.bar(xdata,vals[4],width,bottom=(np.array(vals[0])+np.array(vals[1])+np.array(vals[2])+np.array(vals[3])),color=colour_verif[num],hatch='/')
        #autolabel(p7,plt)
        unlynxTotal(p3,p4,p5,p6,p7)
    #Unlynx All trusted
    if(num==2):
        p8 = plt.bar(xdata,vals[0],width, color=colour_classes[1],hatch='-')
        #autolabel(p8,plt)
        p9 = plt.bar(xdata,vals[1], width,bottom=(np.array(vals[0])),color=colour_agg[1],hatch='-')
        #autolabel(p9,plt)
        p10 = plt.bar(xdata,vals[2],width,bottom=(np.array(vals[0])+np.array(vals[1])),color=colour_dp[0],hatch='-')
        #autolabel(p10,plt)
        p11 = plt.bar(xdata,vals[3],width,bottom=(np.array(vals[0])+np.array(vals[1])+np.array(vals[2])),color=colour_sw[0],hatch='-')
        #autolabel(p11,plt)
        p12 = plt.bar(xdata,vals[4],width,bottom=(np.array(vals[0])+np.array(vals[1])+np.array(vals[2])+np.array(vals[3])),color=colour_verif[1],hatch='-')
        #autolabel(p12,plt)
        unlynxTotal(p8,p9,p10,p11,p12)
        prio =  patches.Rectangle(
        (0.3, 0.3), 1, 1, fill=False,label='Prio')
        unlynxTrus =  patches.Rectangle(
        (0.1, 0.1), 1, 1,
        hatch='//', fill=False,label='Unlynx Trusted')
        Unlynx =  patches.Rectangle(
        (1, 1), 1, 1,
        hatch='---', fill=False,label='Unlynx')
       
        
        init = mlines.Line2D([], [], color=colour_classes[1],marker='s', linestyle='None',
                          markersize=12, label='Initialisation')
        verif = mlines.Line2D([], [], color=colour_verif[1], marker='s', linestyle='None',
                          markersize=12, label='Proof Verification')
        dp = mlines.Line2D([], [], color=colour_dp[0], marker='s', linestyle='None',
                          markersize=12, label='Data provider proof computation')
        switch = mlines.Line2D([], [], color=colour_sw[0], marker='s', linestyle='None',
                          markersize=12, label='Key switch')
        agg = mlines.Line2D([], [], color=colour_agg[1], marker='s', linestyle='None',
                          markersize=12, label='Aggregation')
        
        plt.legend(handles=[prio,unlynxTrus,Unlynx,init,verif,dp,agg,switch],prop={'size': 8})
        
        
        plt.xlabel('Number of Servers',fontsize=14)
        plt.ylabel('Execution time in ms',fontsize=14)
        #plt.title('Comparison of Prio, Unlynx Trusted and Unlynx Anytrust execution time in function of the size of the CA')

# You should no longer need to manually set the plot limit since everything 
# is scaled to one.
# Also the ticks should be much simpler now that each group of bars extends from
# 0.0 to 1.0, 1.0 to 2.0, and so forth and, thus, are centered at 0.5, 1.5, etc.
s.set_xticks(ind+0.5)
s.set_xticklabels(group_labels)
plt.savefig('ComparisonServer.png')
# Out:
# [ 0.05  1.05  2.05  3.05  4.05  5.05  6.05]
# [ 0.35  1.35  2.35  3.35  4.35  5.35  6.35]
# [ 0.65  1.65  2.65  3.65  4.65  5.65  6.65]

# %%
plt.figure(figsize=(7,7), dpi=400)
ratio = np.ceil(np.array([10,10,10,10,10,10,10])/np.array(yy))
xxvall = np.multiply(xxv,ratio)
groups = [[xxi[:3],xxp[:3],xx[:3]],[xxsi[:3],xxdp[:3],xxvall[:3],xxa[:3],xxs[:3]],[xxsi[:3],np.multiply(xxdp[:3],[3,5,10]),np.multiply(xxv[:3],10),xxa[:3],xxs[:3]]]
group_labels = [3,5,10]
num_items = len(group_labels)
# This needs to be a numpy range for xdata calculations
# to work.
ind = np.arange(num_items)

# Bar graphs expect a total width of "1.0" per group
# Thus, you should make the sum of the two margins
# plus the sum of the width for each entry equal 1.0.
# One way of doing that is shown below. You can make
# The margins smaller if they're still too big.
margin = 0.05
width = 0.25
#Colour for init
colour_classes = ['#ffcccc','#ff6666','#ff0000']
#Colour for aggregation
colour_agg = ['#adebad','#5cd65c',"#29a329"]
#Colour for Verif
colour_verif = ['#668cff','#3366ff','#0040ff']
#Colour DP
colour_dp = ['#ffb84d','#e68a00']
#Colour switch
colour_sw = ['#d2a679','#ac7339']


s = plt.subplot(1,1,1)

for num, vals in enumerate(groups):
    
    # The position of the xdata must be calculated for each of the two data series
    xdata = ind+margin+(num*0.30)
    # Removing the "align=center" feature will left align graphs, which is what
    # this method of calculating positions assumes
    
    #PRIO
    if(num==0):
        p0 = plt.bar(xdata, vals[0], width, color=colour_classes[1])
        
        p1 = plt.bar(xdata, vals[1], width,bottom=vals[0], color=colour_verif[1])
        autolabel(p1,plt)
        p2 = plt.bar(xdata, vals[2], width,bottom=(np.array(vals[0])+np.array(vals[1])),color=colour_agg[1])
        autolabel(p2,plt)
    #plt.yscale('log')
    #Unlynx Anytrust
    if(num==1):
        p3 = plt.bar(xdata,vals[0],width, color=colour_classes[num],hatch='/')
        
        p4 = plt.bar(xdata,vals[1], width,bottom=np.array(vals[0]),color=colour_dp[num-1],hatch='/')
        autolabel(p4,plt)
        p5 = plt.bar(xdata,vals[2],width,bottom=(np.array(vals[0])+np.array(vals[1])),color=colour_verif[num],hatch='/')
        autolabel(p5,plt)
        p6 = plt.bar(xdata,vals[3],width,bottom=(np.array(vals[0])+np.array(vals[1])+np.array(vals[2])),color=colour_agg[num],hatch='/')
        autolabel(p6,plt)
        p7 = plt.bar(xdata,vals[4],width,bottom=(np.array(vals[0])+np.array(vals[1])+np.array(vals[2]) +np.array(vals[3])),color=colour_sw[num-1],hatch='/')
        autolabel(p7,plt)
    #Unlynx All trusted
    if(num==2):
        p8 = plt.bar(xdata,vals[0],width, color=colour_classes[1],hatch='-')
        
        p9 = plt.bar(xdata,vals[1], width,bottom=vals[0],color=colour_dp[0],hatch='-')
        autolabel(p9,plt)
        p10 = plt.bar(xdata,vals[2],width,bottom=(np.array(vals[0])+np.array(vals[1])),color=colour_verif[0],hatch='-')
        autolabel(p10,plt)
        p11 = plt.bar(xdata,vals[3],width,bottom=(np.array(vals[0])+np.array(vals[1])+np.array(vals[2])),color=colour_agg[1],hatch='-')
        autolabel(p11,plt)
        p12 = plt.bar(xdata,vals[4],width,bottom=(np.array(vals[0])+np.array(vals[1])+np.array(vals[2]) +np.array(vals[3])),color=colour_sw[0],hatch='-')
        autolabel(p12,plt)
        prio =  patches.Rectangle(
        (0.3, 0.3), 1, 1, fill=False,label='Prio')
        unlynxTrus =  patches.Rectangle(
        (0.1, 0.1), 1, 1,
        hatch='//', fill=False,label='Unlynx Trusted')
        Unlynx =  patches.Rectangle(
        (1, 1), 1, 1,
        hatch='---', fill=False,label='Unlynx')
       
        
        init = mlines.Line2D([], [], color=colour_classes[1],marker='s', linestyle='None',
                          markersize=12, label='Initialisation')
        verif = mlines.Line2D([], [], color=colour_verif[1], marker='s', linestyle='None',
                          markersize=12, label='Proof Verification')
        dp = mlines.Line2D([], [], color=colour_dp[0], marker='s', linestyle='None',
                          markersize=12, label='Data provider proof computation')
        switch = mlines.Line2D([], [], color=colour_sw[0], marker='s', linestyle='None',
                          markersize=12, label='Key switch')
        agg = mlines.Line2D([], [], color=colour_agg[1], marker='s', linestyle='None',
                          markersize=12, label='Aggregation')
        
        plt.legend(handles=[prio,unlynxTrus,Unlynx,init,verif,dp,agg,switch])
        
        plt.xlabel('Number of Servers',fontsize=14)
        plt.ylabel('Execution time in ms',fontsize=14)
        #plt.title('Comparison of Prio, Unlynx Trusted and Unlynx Anytrust execution time in function of the number of Data providers')

# You should no longer need to manually set the plot limit since everything 
# is scaled to one.
# Also the ticks should be much simpler now that each group of bars extends from
# 0.0 to 1.0, 1.0 to 2.0, and so forth and, thus, are centered at 0.5, 1.5, etc.
s.set_xticks(ind+0.5)
s.set_xticklabels(group_labels)
plt.savefig('ComparisonlinearServer')
