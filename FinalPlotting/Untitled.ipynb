# %% [markdown]
# # Plotting result Unlynx vs Prio

# %%
import numpy as np
import matplotlib.pyplot as plt
import pylab
import re
import numpy as np
# %matplotlib inline

def plot(path):
    data = []
    for p in path :
        fp = open(p)
        unit = "ms"

        for line in fp.readlines():
            if(line!=""):
                dataS = (re.findall(r'\d*[.]\d*',line))
                newUnit = (re.findall(r'[a-z|µ]{1,}',line))[0]
                if(newUnit[0]=='s'):
                    data.append(float(dataS[0])*1000)
                elif(newUnit[:2]=="µs"):
                    data.append(float(dataS[0])/1000)
                else :
                    data.append(float(dataS[0]))
    fig3, ax3 = plt.subplots()
    ax3.set_title("time in " + unit)
    print("mean is",np.mean(data))
    print("std is",np.std(data))
    ax3.boxplot(data)
    return np.mean(data),np.std(data)

# %% [markdown]
# ## Variation with number of Client

# %% [markdown]
# x ad z will contains data about prio agg in function of # Client

# %%
x = []
z = []
y = [5,10,50,100,500]
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)

mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/100c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/500c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
# Out:
# mean is 7.782105
# std is 1.27176411428
# mean is 7.782105
# std is 1.27176411428
# mean is 7.782105
# std is 1.27176411428
# mean is 7.782105
# std is 1.27176411428
# mean is 9.02366
# std is 2.77170715477

# %% [markdown]
# xp and zp will contain info about aggregation in unlynx in function in # of server

# %%
xp = []
zp = []

mean,std = plot(["IMPORT/5c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)

mean,std = plot(["IMPORT/10c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/50c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/100c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/500c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
# Out:
# mean is 122.0283182
# std is 17.9526420622
# mean is 212.1655695
# std is 40.6080816155
# mean is 939.9335146
# std is 70.0568874571
# mean is 1912.5141612
# std is 242.313890645
# mean is 9749.6085196
# std is 714.127694907

# %%
xs = []
zs = []

mean,std = plot(["IMPORT/5c5s/switch.txt"])
xs.append(mean)
zs.append(std)

mean,std = plot(["IMPORT/10c5s/switch.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/50c5s/switch.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/100c5s/switch.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/500c5s/switch.txt"])
xs.append(mean)
zs.append(std)
# Out:
# mean is 79.9178112
# std is 9.64875805086
# mean is 78.07715
# std is 7.24536655313
# mean is 74.9370974
# std is 11.8415291057
# mean is 74.772712
# std is 5.28918661032
# mean is 80.09659
# std is 9.95530045109

# %%
xa = []
za = []

mean,std = plot(["IMPORT/5c5s/agg.txt"])
xa.append(mean)
za.append(std)

mean,std = plot(["IMPORT/10c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/50c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/100c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/500c5s/agg.txt"])
xa.append(mean)
za.append(std)
# Out:
# mean is 10.5581594
# std is 1.92321705197
# mean is 11.0116602
# std is 1.61094566361
# mean is 11.6688492
# std is 0.953897528817
# mean is 11.097783
# std is 1.77048734
# mean is 14.17355
# std is 4.84464603771

# %%
xv = []
zv = []

mean,std = plot(["IMPORT/5c5s/verif.txt"])
xv.append(mean)
zv.append(std)

mean,std = plot(["IMPORT/10c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/50c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/100c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/500c5s/verif.txt"])
xv.append(mean)
zv.append(std)
# Out:
# mean is 177.192658
# std is 36.8344541421
# mean is 150.975262444
# std is 4.24683073295
# mean is 153.88355756
# std is 15.7507676805
# mean is 149.75511935
# std is 10.6779089343
# mean is 153.80369994
# std is 9.66852265237

# %%
fig, ax = plt.subplots()

plt.yscale('log')

plt.xlabel('Number of data provider',fontsize=15)
plt.ylabel('Execution time in ms',fontsize=15)

# create an index for each tick position
yi = [i for i in range(0, len(y))]
ax.set_xticks([5,10,50,100,500])
plt.xticks(yi, y)
ax.plot(yi,x,'k--',label='Prio Aggregatio,')
ax.plot(yi,xp,label='Prio Proof')
ax.plot(yi,xs,label='Unlynx Switch')
ax.plot(yi,xa,label='Unlynx Agg')
ax.plot(yi,xv,label='Unlynx Range')
#ax.plot(y,xpp,label='prioProof')
fig.suptitle("Evolution of the execution time in function of number of server", fontsize=16)
legend = plt.legend(bbox_to_anchor=(1.5, 0.4), loc=1, borderaxespad=0.,fontsize=12)

plt.savefig('prioServer.png')

##DP time to create request prio and Un
### Init time at server

### Table for init time and proof size for each proto FOR 1 DP and server number = 5

# %% [markdown]
# ## Variation in number of server

# %%
x = []
z = []
y = [5,10,15,20,30,50]
mean,std = plot(["IMPORT/10c5s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/10c10s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/10c15s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/10c20s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/10c30s/prioAgg.txt"])
x.append(mean)
z.append(std)
mean,std = plot(["IMPORT/10c50s/prioAgg.txt"])
x.append(mean)
z.append(std)
# Out:
# mean is 14.1029034
# std is 3.03059204339
# mean is 38.6394498
# std is 7.8707874282
# mean is 68.5663962
# std is 5.28213062286
# mean is 124.7278748
# std is 6.80418804398
# mean is 248.758319667
# std is 11.4278860284
# mean is 614.602648667
# std is 69.1134426336

# %%
xp = []
zp = []

mean,std = plot(["IMPORT/10c5s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/10c10s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/10c15s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/10c20s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/10c30s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
mean,std = plot(["IMPORT/10c50s/prioVerif.txt"])
xp.append(mean)
zp.append(std)
# Out:
# mean is 212.1655695
# std is 40.6080816155
# mean is 749.6918366
# std is 87.5800787036
# mean is 1482.0164756
# std is 334.214735533
# mean is 2174.2612264
# std is 224.819520426
# mean is 4715.878708
# std is 730.011123422
# mean is 12016.6093774
# std is 4364.28049609

# %%
xa = []
za = []

mean,std = plot(["IMPORT/10c5s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/10c10s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/10c15s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/10c20s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/10c30s/agg.txt"])
xa.append(mean)
za.append(std)
mean,std = plot(["IMPORT/10c50s/agg.txt"])
xa.append(mean)
za.append(std)
# Out:
# mean is 11.0116602
# std is 1.61094566361
# mean is 35.1146322
# std is 2.74138026503
# mean is 71.1869032
# std is 8.504850559
# mean is 117.6722
# std is 5.26294886782
# mean is 250.3524946
# std is 5.96447254717
# mean is 766.665530833
# std is 17.2978610766

# %%
xv = []
zv = []

mean,std = plot(["IMPORT/10c5s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/10c10s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/10c15s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/10c20s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/10c30s/verif.txt"])
xv.append(mean)
zv.append(std)
mean,std = plot(["IMPORT/10c50s/verif.txt"])
xv.append(mean)
zv.append(std)
# Out:
# mean is 150.975262444
# std is 4.24683073295
# mean is 363.6684861
# std is 70.6054734533
# mean is 565.5216933
# std is 110.539628189
# mean is 732.2755563
# std is 57.3593132886
# mean is 1291.8224733
# std is 321.367091675
# mean is 2643.3447685
# std is 760.193187184

# %%
xs = []
zs = []

mean,std = plot(["IMPORT/10c5s/switch.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/10c10s/switch.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/10c15s/switch.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/10c20s/switch.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/10c30s/switch.txt"])
xs.append(mean)
zs.append(std)
mean,std = plot(["IMPORT/10c50s/switch.txt"])
xs.append(mean)
zs.append(std)
# Out:
# mean is 78.07715
# std is 7.24536655313
# mean is 194.3044256
# std is 14.8150422743
# mean is 345.7328686
# std is 52.1405835798
# mean is 444.4635832
# std is 32.8478961561
# mean is 820.3907156
# std is 56.2277565298
# mean is 1785.20395
# std is 63.8223125688

# %%
fig, ax = plt.subplots()

plt.yscale('log')

plt.xlabel('Number of data provider',fontsize=15)
plt.ylabel('Execution time in ms',fontsize=15)

# create an index for each tick position
ax.plot(y,x,'k--',label='Prio Aggregatio,')
ax.plot(y,xp,label='Prio Proof')
ax.plot(y,xs,label='Unlynx Switch')
ax.plot(y,xa,label='Unlynx Agg')
ax.plot(y,xv,label='Unlynx Range')
#ax.plot(y,xpp,label='prioProof')
fig.suptitle("Evolution of the execution time in function of number of server", fontsize=16)
legend = plt.legend(bbox_to_anchor=(1.5, 0.4), loc=1, borderaxespad=0.,fontsize=12)

plt.savefig('prioServer.png')
